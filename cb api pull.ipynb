# %% [markdown]
# ## Pulling from CB API

# %%
import json
import requests
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import pymysql
from stackapi import StackAPI
import pandas as pd

# %%
organisation = pd.read_csv(r'data/organizations.csv')

# %%
organisation.head()
# Out:
#                                    uuid      name          type primary_role  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint  organization      company
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7      Zoho  organization      company
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0      Digg  organization      company
# 3  df662812-7f97-0b43-9d3e-12f64f504fbb  Facebook  organization      company
# 4  b08efc27-da40-505a-6f9d-c9e14247bf36     Accel  organization     investor
#
#                                               cb_url        domain  \
# 0  https://www.crunchbase.com/organization/wetpai...  wetpaint.com
# 1  https://www.crunchbase.com/organization/zoho?u...      zoho.com
# 2  https://www.crunchbase.com/organization/digg?u...      digg.com
# 3  https://www.crunchbase.com/organization/facebo...  facebook.com
# 4  https://www.crunchbase.com/organization/accel-...     accel.com
#
#                homepage_url  \
# 0  http://www.wetpaint.com/
# 1     https://www.zoho.com/
# ...

# %%
organisation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 951306 entries, 0 to 951305
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   uuid                    951306 non-null  object
#  1   name                    951304 non-null  object
#  2   type                    951306 non-null  object
#  3   primary_role            951306 non-null  object
#  4   cb_url                  951306 non-null  object
#  5   domain                  951305 non-null  object
#  6   homepage_url            951306 non-null  object
#  7   logo_url                951306 non-null  object
#  8   facebook_url            542589 non-null  object
#  9   twitter_url             513931 non-null  object
#  10  linkedin_url            464269 non-null  object
#  11  combined_stock_symbols  30866 non-null   object
#  12  city                    789100 non-null  object
#  13  region                  789100 non-null  object
# ...

# %%
# data useless - not enough details
