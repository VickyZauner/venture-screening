# %% [markdown]
# ## Biotech Market - Venture Screening

# %%
import pandas as pd
import numpy as np

# %%
biotech = pd.read_csv(r'data/companies_biotech.csv')

# %%
biotech.head()
# Out:
#         Organization Name                              Organization Name URL  \
# 0  Inovio Pharmaceuticals  https://www.crunchbase.com/organization/inovio...
# 1          Legend Biotech  https://www.crunchbase.com/organization/legend...
# 2          Bharat Biotech  https://www.crunchbase.com/organization/bharat...
# 3                NodThera   https://www.crunchbase.com/organization/nodthera
# 4              MainStreet  https://www.crunchbase.com/organization/mainst...
#
#                                           Industries  \
# 0  Biotechnology, Health Care, Pharmaceutical, Th...
# 1           Biotechnology, Health Care, Life Science
# 2                                      Biotechnology
# 3                        Biotechnology, Life Science
# 4  Enterprise Software, Financial Services, FinTe...
#
#                            Headquarters Location  \
# 0  Plymouth Meeting, Pennsylvania, United States
# 1          Piscataway, New Jersey, United States
# ...

# %%
biotech.drop(columns=['Organization Name URL'])
# Out:
#           Organization Name  \
# 0    Inovio Pharmaceuticals
# 1            Legend Biotech
# 2            Bharat Biotech
# 3                  NodThera
# 4                MainStreet
# ..                      ...
# 995      EraGen Biosciences
# 996            Vero Biotech
# 997          Cayuga Biotech
# 998            Corus Pharma
# 999             GSL Biotech
#
#                                             Industries  \
# 0    Biotechnology, Health Care, Pharmaceutical, Th...
# 1             Biotechnology, Health Care, Life Science
# 2                                        Biotechnology
# 3                          Biotechnology, Life Science
# 4    Enterprise Software, Financial Services, FinTe...
# ..                                                 ...
# 995  Biotechnology, Health Diagnostics, Market Rese...
# 996          Biotechnology, Commercial, Pharmaceutical
# 997  Biotechnology, Health Care, Medical, Medical D...
# 998         Biotechnology, Health Care, Pharmaceutical
# ...

# %%
 biotech['Description'].astype(str)
# Out:
# 0      Inovio is a biotech company focusing on bringi...
# 1      Legend Biotech is a biopharmaceutical company ...
# 2                India's second biggest vaccines company
# 3      NodThera is a biotechnology company focused on...
# 4      MainStreet is fixing the $300B government ince...
#                              ...
# 995    EraGen Biosciences, a biotech company, develop...
# 996    Vero Biotech is an emerging biotechnology comp...
# 997    Cayuga Biotech develops hemostatic drugs and d...
# 998    Corus Pharma Inc., a Seatle-based biotech and ...
# 999    GSL Biotech provides computer programming serv...
# Name: Description, Length: 1000, dtype: object

# %%
description =  biotech['Description'].astype(str)

# %%
description
# Out:
# 0      Inovio is a biotech company focusing on bringi...
# 1      Legend Biotech is a biopharmaceutical company ...
# 2                India's second biggest vaccines company
# 3      NodThera is a biotechnology company focused on...
# 4      MainStreet is fixing the $300B government ince...
#                              ...
# 995    EraGen Biosciences, a biotech company, develop...
# 996    Vero Biotech is an emerging biotechnology comp...
# 997    Cayuga Biotech develops hemostatic drugs and d...
# 998    Corus Pharma Inc., a Seatle-based biotech and ...
# 999    GSL Biotech provides computer programming serv...
# Name: Description, Length: 1000, dtype: object

# %% [markdown]
# #### Counting hallmarks, categorizing

# %%
# Categorizing Startups by Hallmarks

biotech['Cellular Senescence'] = biotech.Description.apply(lambda x: 0 if 'senescence'or 'Senescence'or 'senescent'or 'Senescent' in x else 1)

# %%
biotech['Cellular Senescence'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: Cellular Senescence, Length: 1000, dtype: int64>

# %%
biotech['Stem Cells'] = biotech.Description.apply(lambda x: 0 if 'stem'or 'stem cell'or 'cell' in x else 1)

# %%
biotech['Stem Cells'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: Stem Cells, Length: 1000, dtype: int64>

# %%
biotech['Aging'] = biotech.Description.apply(lambda x: 0 if 'age'or 'aging'or 'Age' or 'Aging' in x else 1)

# %%
biotech['Aging'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: Aging, Length: 1000, dtype: int64>

# %%
for string in biotech.Description:
    if 'age' in string:
        biotech['Aging'] = 1

# %%
biotech['Aging'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 995    1
# 996    1
# 997    1
# 998    1
# 999    1
# Name: Aging, Length: 1000, dtype: int64>

# %%
apollo = pd.read_csv(r'data/list_apollo.csv')

# %%
apollo.head()
# Out:
#   TODOs: 0. check if the company is relevant for the list (delete if no) 1. Insert the hyperlink in column A\n  \
# 0              2. 1 sentence description in column B
# 1             3. put "yes" to all relevant hallmarks
# 2                                  20/20 GeneSystems
# 3                                      3D Signatures
# 4                                          4P PHARMA
#
#                  Unnamed: 1                  Unnamed: 2  \
# 0                       NaN                         NaN
# 1  DESCRIPTION (1 SENTENCE)  APOLLO'S DEAL FLOW\nSTATUS
# 2                       NaN                        Open
# 3                       NaN                        Open
# 4                       NaN                        Open
#
#                                   Unnamed: 3           Unnamed: 4  \
# 0                                        NaN                  NaN
# 1  Aging Biotech\n .info company\ncategories  hallmarks\nof aging
# ...

# %%
apollo_comps = apollo.drop(apollo.index[[0,1]])
apollo_comps
# Out:
#     TODOs: 0. check if the company is relevant for the list (delete if no) 1. Insert the hyperlink in column A\n  \
# 2                                    20/20 GeneSystems
# 3                                        3D Signatures
# 4                                            4P PHARMA
# 5                                          5 Alarm Bio
# 6                                        712 North Inc
# ..                                                 ...
# 455                                   Xeno Biosciences
# 456                            YourChoice Therapeutics
# 457                                Youthereum Genetics
# 458                                   Yuva Biosciences
# 459                                                  x
#
#     Unnamed: 1 Unnamed: 2     Unnamed: 3    Unnamed: 4           Unnamed: 5  \
# 2          NaN       Open            NaN           NaN                  NaN
# 3          NaN       Open            NaN           NaN                  NaN
# ...

# %%
apollo_comps = apollo_comps.rename(columns={"TODOs: 0. check if the company is relevant for the list (delete if no) 1. Insert the hyperlink in column A\n": "Comps", "Unnamed: 2": "Status", "Unnamed: 3": "Category", "Unnamed: 4": "Hallmark"})

# %%
apollo_comps = apollo_comps[['Comps', "Status", "Category", "Hallmark"]]

# %%
apollo_comps.head(10)
# Out:
#                      Comps Status      Category      Hallmark
# 2        20/20 GeneSystems   Open           NaN           NaN
# 3            3D Signatures   Open           NaN           NaN
# 4                4P PHARMA   Open           NaN           NaN
# 5              5 Alarm Bio    NaN  proteostasis  proteostasis
# 6            712 North Inc   Open  mitochondria  mitochondria
# 7               A2A Pharma   Open           NaN           NaN
# 8   ACADIA Pharmaceuticals   Open           NaN           NaN
# 9               Accelerate   Lost           NaN           NaN
# 10         Access Vascular   Lost           NaN           NaN
# 11        Ace Laboratories   Open           NaN           NaN

# %%
apollo_comps.to_csv(r'data/apollo_list.csv')

# %%
biotech = pd.read_csv(r'data/companies_broad.csv')

# %%
biotech.head()
# Out:
#         Organization Name                              Organization Name URL  \
# 0               Medtronic  https://www.crunchbase.com/organization/medtronic
# 1  Inovio Pharmaceuticals  https://www.crunchbase.com/organization/inovio...
# 2                   Bayer  https://www.crunchbase.com/organization/bayer-...
# 3                   Merck  https://www.crunchbase.com/organization/merck-...
# 4                 CureVac    https://www.crunchbase.com/organization/curevac
#
#                                           Industries  \
# 0  Biotechnology, Health Care, Health Diagnostics...
# 1  Biotechnology, Health Care, Pharmaceutical, Th...
# 2  Biotechnology, Chemical, Health Care, Life Sci...
# 3  Biotechnology, Health Care, Medical, Pharmaceu...
# 4             Biopharma, Biotechnology, Therapeutics
#
#                            Headquarters Location  \
# 0          Minneapolis, Minnesota, United States
# 1  Plymouth Meeting, Pennsylvania, United States
# ...

# %%
longevity_cb = pd.read_csv(r'data/companies_longevity.csv')

# %%
longevity_cb
# Out:
#                              Organization Name  \
# 0                                 Sun Genomics
# 1                                      DocsApp
# 2                                       Practo
# 3                              Human Longevity
# 4                                     Lenskart
# ..                                         ...
# 657                           Rug Cleaning NYC
# 658                   Intelligence Performance
# 659         Cardiac Clinical Management System
# 660     Midtown Dermatology - Susan Bard, M.D.
# 661  Professional Roofing Service Davenport FL
#
#                                  Organization Name URL  \
# 0    https://www.crunchbase.com/organization/sun-ge...
# 1    https://www.crunchbase.com/organization/docsap...
# 2       https://www.crunchbase.com/organization/practo
# 3    https://www.crunchbase.com/organization/human-...
# 4    https://www.crunchbase.com/organization/lenska...
# ..                                                 ...
# ...

# %%
 longevity_cb['Full Description'].astype(str)
# Out:
# 0      Sun Genomics is a microbiome health company fo...
# 1      DocsApp is an online doctor consultation platf...
# 2      For millions of people, Practo is the trusted ...
# 3      Human Longevity (HLI) is the genomic-based, he...
# 4      Lenskart, the first of its kind online optical...
#                              ...
# 657    Address: 2370 2nd Ave New York, NY 10035 RUGCL...
# 658    Intelligence Performance is aiming in the impr...
# 659    CCMS’s core technology is a diagnostic algorit...
# 660    Hours: Mon - Fri 8 a.m - 7 p.m  Pyment: All cc...
# 661                                                  nan
# Name: Full Description, Length: 662, dtype: object

# %%
import re

for string in longevity_cb['Full Description'].astype(str):
    if 'age' in i in string.split():
        longevity_cb['Aging'] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2343ac4cd740> in <module>
#       2
#       3 for string in longevity_cb['Full Description'].astype(str):
# ----> 4     if 'age' in i in string.split():
#       5         longevity_cb['Aging'] = 1
#
# NameError: name 'i' is not defined

# %%
longevity_cb['Full Description']
# Out:
# 0      Sun Genomics is a microbiome health company fo...
# 1      DocsApp is an online doctor consultation platf...
# 2      For millions of people, Practo is the trusted ...
# 3      Human Longevity (HLI) is the genomic-based, he...
# 4      Lenskart, the first of its kind online optical...
#                              ...
# 657    Address: 2370 2nd Ave New York, NY 10035 RUGCL...
# 658    Intelligence Performance is aiming in the impr...
# 659    CCMS’s core technology is a diagnostic algorit...
# 660    Hours: Mon - Fri 8 a.m - 7 p.m  Pyment: All cc...
# 661                                                  NaN
# Name: Full Description, Length: 662, dtype: object

# %%
description_string = []

for string in longevity_cb['Full Description']:
    description_string.append(string)
    
print(description_string)
# Out:
# ['Sun Genomics is a microbiome health company focused on curing dysbiosis through personalized probiotics. its flagship product Floré, a microbiome test and gut probiotics solution that utilizes whole-genome sequencing to evaluate different digestive system data points and ensure that customers receive a completely personalized product that is based on their unique gut profiles. The company also offers Floré Tots, which is available for kids up to age 12 and comes in an easy digestive powder to mix with their favorite drink.', 'DocsApp is an online doctor consultation platform. DocsApp is a mobile platform where people from India can consult a specialist MD Doctors with in 30 minutes in various specialisations through chat or call from the location of their convenience. DocsApp has specialist Doctors in the following specialisations.', 'For millions of people, Practo is the trusted and familiar home where they know they’ll find a healing touch. It connects them with everything they n
# ...

# %%
longevity_cb.head()
# Out:
#   Organization Name                              Organization Name URL  \
# 0      Sun Genomics  https://www.crunchbase.com/organization/sun-ge...
# 1           DocsApp  https://www.crunchbase.com/organization/docsap...
# 2            Practo     https://www.crunchbase.com/organization/practo
# 3   Human Longevity  https://www.crunchbase.com/organization/human-...
# 4          Lenskart  https://www.crunchbase.com/organization/lenska...
#
#                                           Industries  \
# 0                Biotechnology, Health Care, Medical
# 1        Health Care, Medical, Mobile Apps, Wellness
# 2  Health Care, Health Diagnostics, Medical, Mobi...
# 3  Biotechnology, Genetics, Health Care, Health D...
# 4  Delivery, E-Commerce, Eyewear, Fashion, Health...
#
#                   Headquarters Location  \
# 0  San Diego, California, United States
# 1           Bangalore, Karnataka, India
# 2           Bangalore, Karnataka, India
# 3  San Diego, California, United States
# ...

# %%
overlap = longevity_cb[longevity_cb["Organization Name"].isin(apollo_comps["Comps"])]

# %%
overlap
# Out:
#           Organization Name  \
# 0              Sun Genomics
# 7                Celularity
# 20         Spring Discovery
# 46                 Celevity
# 71             LambdaVision
# 91              Life Length
# 99   Deciduous Therapeutics
# 188    Rubedo Life Sciences
# 358                 CellAge
#
#                                  Organization Name URL  \
# 0    https://www.crunchbase.com/organization/sun-ge...
# 7    https://www.crunchbase.com/organization/celula...
# 20   https://www.crunchbase.com/organization/spring...
# 46    https://www.crunchbase.com/organization/celevity
# 71   https://www.crunchbase.com/organization/lambda...
# 91   https://www.crunchbase.com/organization/life-l...
# 99   https://www.crunchbase.com/organization/decidu...
# 188  https://www.crunchbase.com/organization/rubedo...
# 358    https://www.crunchbase.com/organization/cellage
#
#                                             Industries  \
# 0                  Biotechnology, Health Care, Medical
# ...

# %%
apollo_comps.head()
# Out:
#                Comps Status      Category      Hallmark
# 2  20/20 GeneSystems   Open           NaN           NaN
# 3      3D Signatures   Open           NaN           NaN
# 4          4P PHARMA   Open           NaN           NaN
# 5        5 Alarm Bio    NaN  proteostasis  proteostasis
# 6      712 North Inc   Open  mitochondria  mitochondria

# %%
comp_list = []

for i in list_of_Comps:
    comp_list.append(i)

print(comp_list)
# Out:
# ['20/20 GeneSystems', '3D Signatures', '4P PHARMA', '5 Alarm Bio', '712 North Inc', 'A2A Pharma', 'ACADIA Pharmaceuticals', 'Accelerate', 'Access Vascular', 'Ace Laboratories', 'Achelios Therapeutics', 'ActiTrexx', 'ActuRx', 'Aenitis Technologies', 'Aeovian', 'Age Labs', 'AgeCurve Limited', 'Ageis Bio', 'AgeX Ther. / Reverse Bio', 'AI Biomarker - Helmholtz Zentrum München', 'Aldabra Biosciences', 'Alector', 'Aleeva Medical', 'Alimonti - Geroprotector', 'Alkahest', 'Allogeneic gamma delta t-cell therapy', 'Alma Bio Therapeutics', 'Altheia Science', 'Altoida', 'ALZPROTECT PHARMA', 'Ambrosia', 'American Gene Technologies', 'Amivas', 'Amprion', 'Anaeropharma Science', 'ANAETOS', 'Anagenesis', 'AnHeart Therapeutics', 'Animal Biosciences', 'Animal drugs', 'Antag Therapeutics', 'Antiverse', 'Antoxis', 'Aortyx', 'Aposense', 'Aptorum Group', 'Aqualung Therapeutics', 'Arviat Pharmaceuticals', 'Asha Nutrition Sciences', 'Ashvattha', 'Athersys Inc', 'Athira Pharma', 'Atropos Therapeutics', 'Aura
# ...

# %%
def clean_up(s):
    pattern = r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))'''
    cleaned = re.sub(pattern, ' ', s) # tokenizing
    cleaned = re.sub(r"[^A-Za-z0-9]+", " ", cleaned)
    cleaned = re.sub(" \d+", " ", cleaned)
    cleaned = cleaned.lower().strip()
    cleaned = cleaned[:20]

    return cleaned

# %%
again = []

for s in comp_list:
    again.append(clean_up(s))

# %%
again
# Out:
# ['20  genesystems',
#  '3d signatures',
#  '4p pharma',
#  '5 alarm bio',
#  '712 north inc',
#  'a2a pharma',
#  'acadia pharmaceutica',
#  'accelerate',
#  'access vascular',
#  'ace laboratories',
#  'achelios therapeutic',
#  'actitrexx',
#  'acturx',
#  'aenitis technologies',
#  'aeovian',
#  'age labs',
#  'agecurve limited',
#  'ageis bio',
#  'agex ther reverse bi',
#  'ai biomarker helmhol',
#  'aldabra biosciences',
#  'alector',
#  'aleeva medical',
#  'alimonti geroprotect',
#  'alkahest',
#  'allogeneic gamma del',
#  'alma bio therapeutic',
#  'altheia science',
#  'altoida',
#  'alzprotect pharma',
#  'ambrosia',
#  'american gene techno',
#  'amivas',
#  'amprion',
#  'anaeropharma science',
#  'anaetos',
#  'anagenesis',
#  'anheart therapeutics',
#  'animal biosciences',
#  'animal drugs',
#  'antag therapeutics',
#  'antiverse',
#  'antoxis',
#  'aortyx',
#  'aposense',
#  'aptorum group',
#  'aqualung therapeutic',
#  'arviat pharmaceutica',
# ...

# %%
longevity_cb["Token"] = longevity_cb["Organization Name"].apply(lambda x: clean_up(x))

# %%
longevity_cb.head()
# Out:
#   Organization Name                              Organization Name URL  \
# 0      Sun Genomics  https://www.crunchbase.com/organization/sun-ge...
# 1           DocsApp  https://www.crunchbase.com/organization/docsap...
# 2            Practo     https://www.crunchbase.com/organization/practo
# 3   Human Longevity  https://www.crunchbase.com/organization/human-...
# 4          Lenskart  https://www.crunchbase.com/organization/lenska...
#
#                                           Industries  \
# 0                Biotechnology, Health Care, Medical
# 1        Health Care, Medical, Mobile Apps, Wellness
# 2  Health Care, Health Diagnostics, Medical, Mobi...
# 3  Biotechnology, Genetics, Health Care, Health D...
# 4  Delivery, E-Commerce, Eyewear, Fashion, Health...
#
#                   Headquarters Location  \
# 0  San Diego, California, United States
# 1           Bangalore, Karnataka, India
# 2           Bangalore, Karnataka, India
# 3  San Diego, California, United States
# ...

# %%
overlap = longevity_cb[longevity_cb["Token"].isin(again)]

# %%
overlap
# Out:
#           Organization Name  \
# 0              Sun Genomics
# 7                Celularity
# 10               Neurotrack
# 20         Spring Discovery
# 46                 Celevity
# 71             LambdaVision
# 91              Life Length
# 99   Deciduous Therapeutics
# 188    Rubedo Life Sciences
# 358                 CellAge
#
#                                  Organization Name URL  \
# 0    https://www.crunchbase.com/organization/sun-ge...
# 7    https://www.crunchbase.com/organization/celula...
# 10   https://www.crunchbase.com/organization/neurot...
# 20   https://www.crunchbase.com/organization/spring...
# 46    https://www.crunchbase.com/organization/celevity
# 71   https://www.crunchbase.com/organization/lambda...
# 91   https://www.crunchbase.com/organization/life-l...
# 99   https://www.crunchbase.com/organization/decidu...
# 188  https://www.crunchbase.com/organization/rubedo...
# 358    https://www.crunchbase.com/organization/cellage
#
# ...

# %% [markdown]
# Crunchbase Data Includes:
# any Biotechnology, Biopharma, Pharmaceutical, Therapeutics, Life Sciences
# founded after 2000
# includes any aging, longevity, lifespan, senescence, senescent, telomere, telomerase, stem cell, dna, proteostasis, epigenes, epigenetic

# %%
adv = pd.read_csv(r'data/advanced_search.csv')

# %%
adv
# Out:
#           Organization Name  \
# 0                    Akouos
# 1      Poseida Therapeutics
# 2                    Practo
# 3                     Helix
# 4       CRISPR Therapeutics
# ..                      ...
# 936                 Phistem
# 937          Coisa de Velho
# 938                   eGene
# 939  Second Life Bank - DNA
# 940         Think Law Group
#
#                                  Organization Name URL  \
# 0       https://www.crunchbase.com/organization/akouos
# 1    https://www.crunchbase.com/organization/poseid...
# 2       https://www.crunchbase.com/organization/practo
# 3        https://www.crunchbase.com/organization/helix
# 4    https://www.crunchbase.com/organization/crispr...
# ..                                                 ...
# 936    https://www.crunchbase.com/organization/phistem
# 937  https://www.crunchbase.com/organization/coisa-...
# 938      https://www.crunchbase.com/organization/egene
# 939  https://www.crunchbase.com/organization/second...
# ...
